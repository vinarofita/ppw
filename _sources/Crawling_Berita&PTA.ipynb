# %% [markdown]
# # Import Library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re, sys, time

# %%
BASE_URL = "https://pta.trunojoyo.ac.id/c_search/byprod"

# %% [markdown]
# # Crawling data melalui PTA UTM

# %%
# Daftar prodi Fakultas Teknik
PRODI_FATEK = {
    10: "Teknik Informatika",
    11: "Teknik Industri",
    12: "Teknik Mesin",
    13: "Teknik Elektro",
    14: "Teknik Mekatronika",
    15: "Sistem Informasi",
    16: "Teknik Multimedia dan Jaringan",
    17: "Manajemen Informatika",
    18: "Mekatronika"
}

# Batas maksimal halaman per prodi (biar tidak lama)
MAX_PAGE_LIMIT = 15   # <-- ganti jadi 10 kalau mau lebih banyak

def get_max_page(prodi_id):
    url = f"{BASE_URL}/{prodi_id}/1"
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")

    last_page = soup.select_one('ol.pagination a:contains("»")')
    if last_page and "href" in last_page.attrs:
        href = last_page["href"]
        max_page = int(href.split("/")[-1])
        return max_page
    return 1

def print_progress(prodi_id, prodi, current_page, total_pages):
    percent = (current_page / total_pages) * 100
    bar_length = 20
    filled_length = int(bar_length * current_page // total_pages)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    sys.stdout.write(f'\r[{prodi_id}] {prodi} - Page {current_page}/{total_pages} [{bar}] {percent:.2f}%')
    sys.stdout.flush()
    if current_page == total_pages:
        sys.stdout.write('\n')

def pta_fak_teknik():
    start_time = time.time()

    data = {
        "id": [], "penulis": [], "judul": [], "abstrak_id": [],
        "abstrak_en": [], "pembimbing_pertama": [], "pembimbing_kedua": [],
        "prodi": []
    }

    for prodi_id, prodi_name in PRODI_FATEK.items():
        max_page = min(get_max_page(prodi_id), MAX_PAGE_LIMIT)  # batasi halaman
        for j in range(1, max_page + 1):
            url = f"{BASE_URL}/{prodi_id}/{j}"
            r = requests.get(url)
            soup = BeautifulSoup(r.content, "html.parser")
            jurnals = soup.select('li[data-cat="#luxury"]')

            for jurnal in jurnals:
                link_keluar = jurnal.select_one('a.gray.button')['href']
                id_match = re.search(r"/detail/(\d+)", link_keluar)
                pta_id = id_match.group(1) if id_match else None

                response = requests.get(link_keluar)
                soup1 = BeautifulSoup(response.content, "html.parser")
                isi = soup1.select_one('div#content_journal')

                judul = isi.select_one('a.title').text.strip() if isi.select_one('a.title') else "N/A"
                penulis = isi.find(string=re.compile("Penulis")) if isi else "N/A"
                pembimbing_pertama = isi.find(string=re.compile("Dosen Pembimbing I")) if isi else "N/A"
                pembimbing_kedua = isi.find(string=re.compile("Dosen Pembimbing II")) if isi else "N/A"

                paragraf = isi.select('p[align="justify"]') if isi else []
                abstrak_id = paragraf[0].get_text(strip=True) if len(paragraf) > 0 else "N/A"
                abstrak_en = paragraf[1].get_text(strip=True) if len(paragraf) > 1 else "N/A"

                data["id"].append(pta_id)
                data["penulis"].append(penulis)
                data["judul"].append(judul)
                data["abstrak_id"].append(abstrak_id)
                data["abstrak_en"].append(abstrak_en)
                data["pembimbing_pertama"].append(pembimbing_pertama)
                data["pembimbing_kedua"].append(pembimbing_kedua)
                data["prodi"].append(prodi_name)

            print_progress(prodi_id, prodi_name, j, max_page)

        sys.stdout.write("\n")

    # simpan hasil
    df = pd.DataFrame(data)
    df.to_csv("pta_fak_teknik.csv", index=False, encoding="utf-8-sig")

    elapsed = int(time.time() - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    print("\n✅ Data Fakultas Teknik berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱️ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

# %% [markdown]
# # Hasil Crawling data

# %%
pta_fak_teknik()
# Out:
# [10] Teknik Informatika - Page 15/15 [████████████████████] 100.00%
#
# [11] Teknik Industri - Page 15/15 [████████████████████] 100.00%
#
# [12] Teknik Mesin - Page 15/15 [████████████████████] 100.00%
#
# [13] Teknik Elektro - Page 15/15 [████████████████████] 100.00%
#
# [14] Teknik Mekatronika - Page 15/15 [████████████████████] 100.00%
#
# [15] Sistem Informasi - Page 15/15 [████████████████████] 100.00%
#
# [16] Teknik Multimedia dan Jaringan - Page 15/15 [████████████████████] 100.00%
#
# [17] Manajemen Informatika - Page 15/15 [████████████████████] 100.00%
#
# [18] Mekatronika - Page 15/15 [████████████████████] 100.00%
#
#
# ✅ Data Fakultas Teknik berhasil dikumpulkan!
# 📊 Total entri: 675
# ⏱️ Waktu eksekusi: 1 jam 21 menit 20 detik
#                id                                penulis  \
# 0    040411100468           Penulis : A.Ubaidillah S.Kom
# 1    040411100476          Penulis : M. Basith Ardianto,
# 2    040411100480        Penulis : Akhmad Suyandi, S.Kom
# 3    070411100070              Penulis : Heri Supriyanto
# 4    080411100115         Penulis : Septian Rahman Hakim
# ..            ...                                    ...
# 670  110611100137                 Penulis : Enik Ningsih
# 671  110611100111  Penulis : Titis Kurnia Eka Fajariesta
# 672  110611100112                   Penulis : MARIA ULFA
# 673  110611100083          Penulis : Rista Apriliya Devi
# 674  110611100018       Penulis : Anggit Lintang Pertiwi
#
#                                                  judul  \
# 0    PERANCANGAN DAN IMPLEMENTASI SISTEM DATABASE \...
# 1    APLIKASI KONTROL DAN MONITORING JARINGAN KOMPU...
# 2    RANCANG BANGUN APLIKASI PROXY SERVER UNTUK\r\n...
# 3    SISTEM PENDUKUNG KEPUTUSAN OPTIMASI PENJADWALA...
# 4    SISTEM AUGMENTED REALITY ANIMASI BENDA BERGERA...
# ..                                                 ...
# 670  Perbandingan Hasil Belajar Siswa Menggunakan M...
# 671  PENGARUH TEMAN SEBAYA TERHADAP KEMAMPUAN KOGNI...
# 672  PENGARUH METODE MIND MAPPING TERHADAP HASIL BE...
# 673  PENGEMBANGAN PERANGKAT PEMBELAJARAN TEMATIK BE...
# 674  EFEKTIVITAS MODEL PEMBELAJARAN KOOPERATIF TIPE...
#
#                                             abstrak_id  \
# 0    Sistem  informasi  akademik  (SIAKAD) merupaka...
# 1    Berjalannya koneksi jaringan komputer dengan l...
# 2    Web server adalah sebuah perangkat lunak serve...
# 3    Penjadwalan  kuliah  di  Perguruan  Tinggi  me...
# 4    Seiring perkembangan teknologi yang ada diduni...
# ..                                                 ...
# 670  Penelitian ini bertujuan untuk mengetahui apak...
# 671  Latar belakang penelitian ini adalah Setiap ke...
# 672  Permasalahan yang terjadi saat ini adalah hasi...
# 673  Perangkat pembelajaran merupakan serangkaian b...
# 674  Lintang Pertiwi, Anggit. 2015 Efektivitas Mode...
#
#                                             abstrak_en  \
# 0    Academic information systems (SIAKAD) is an in...
# 1                                                    -
# 2    Web server is a server software functioning to...
# 3    Scheduling  courses  in  universities  is  a  ...
# 4    As the development of technology existing in t...
# ..                                                 ...
# 670  The purpose of this study to determine whether...
# 671  Background of this study was that every learni...
# 672  The problem happen in this moment is a still l...
# 673  Learning tools is a series of materials, equip...
# 674  Lintang pertiwi, anggit. 2015 The Effectivenes...
#
#                                     pembimbing_pertama  \
# 0                Dosen Pembimbing I : Budi Setyono M.T
# 1           Dosen Pembimbing I : Drs. Budi Soesilo, MT
# 2          Dosen Pembimbing I : Drs. Budi Soesilo, M.T
# 3            Dosen Pembimbing I : Mulaab, S.Si., M.Kom
# 4    Dosen Pembimbing I : Arik Kurniawati, S.Kom., ...
# ..                                                 ...
# 670  Dosen Pembimbing I : Mohammad Edy Nurtamam, S....
# 671  Dosen Pembimbing I : H. Priyono Tri Febrianto,...
# 672  Dosen Pembimbing I : Eva Ari Wahyuni, S.Pd., M.Si
# 673         Dosen Pembimbing I : Hani’ah, S.Pd., M.Pd.
# 674  Dosen Pembimbing I : H. Priyono Tri Febrianto,...
#
#                                       pembimbing_kedua               prodi
# 0                    Dosen Pembimbing II :Hermawan S.T  Teknik Informatika
# 1                   Dosen Pembimbing II :Koko Joni, ST  Teknik Informatika
# 2                Dosen Pembimbing II :Hermawan, ST, MT  Teknik Informatika
# 3       Dosen Pembimbing II :Firli Irhamni, ST., M.Kom  Teknik Informatika
# 4            Dosen Pembimbing II :Haryanto, S.T., M.T.  Teknik Informatika
# ..                                                 ...                 ...
# 670  Dosen Pembimbing II :Ariesta Kartika Sari S.Si...         Mekatronika
# 671  Dosen Pembimbing II :Muhammad Busyro Karim, S....         Mekatronika
# 672  Dosen Pembimbing II :Muhammad Busyro Karim, S....         Mekatronika
# 673      Dosen Pembimbing II :Mujtahidin, S.Pd., M.Pd.         Mekatronika
# 674  Dosen Pembimbing II :Muhammad Busyro Karim, S....         Mekatronika
#
# [675 rows x 8 columns]

# %% [markdown]
# # Crawling Link keluaran

# %%
# Progress bar
def print_progress(prodi_id, prodi, current_page, total_pages):
    percent = (current_page / total_pages) * 100
    bar_length = 20
    filled_length = int(bar_length * current_page // total_pages)
    bar = '█' * filled_length + '-' * (bar_length - filled_length)
    sys.stdout.write(f'\r[{prodi_id}] {prodi} - Page {current_page}/{total_pages} [{bar}] {percent:.2f}%')
    sys.stdout.flush()
    if current_page == total_pages:
        sys.stdout.write('\n\n')

# Crawling link page + link keluar
def pta_links():
    start_time = time.time()  # mulai hitung waktu

    data = {
        "no": [],
        "page": [],
        "link_keluar": []
    }

    no = 1  # nomor urut

    for i in range(1, 42):  # looping semua prodi (id 1–41)
        total_pages = 3  # bisa diubah sesuai kebutuhan (misal 10 halaman / semua halaman)
        prodi_name = None

        for j in range(1, total_pages + 1):  # loop halaman per prodi
            url = f"https://pta.trunojoyo.ac.id/c_search/byprod/{i}/{j}"
            r = requests.get(url)
            soup = BeautifulSoup(r.content, "html.parser")
            jurnals = soup.select('li[data-cat="#luxury"]')

            isii = soup.select_one('div#begin')
            if not isii:
                continue
            prodi_full = isii.select_one('h2').text.strip()
            prodi = prodi_full.replace("Journal Jurusan ", "")
            if not prodi_name:
                prodi_name = prodi

            for jurnal in jurnals:
                link = jurnal.select_one('a.gray.button')['href']

                data["no"].append(no)
                data["page"].append(url)          # link halaman
                data["link_keluar"].append(link)  # link detail TA
                no += 1

            # update progress bar
            print_progress(i, prodi_name, j, total_pages)

    df = pd.DataFrame(data)
    df.to_csv("pta_links.csv", index=False)

    end_time = time.time()
    elapsed = int(end_time - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    # summary
    print("\n✅ Seluruh link berhasil dikumpulkan!")
    print(f"📊 Total entri: {len(df)}")
    print(f"⏱ Waktu eksekusi: {jam} jam {menit} menit {detik} detik")

    return df

# %%
pta_links()
# Out:
# [1] Ilmu Hukum - Page 3/3 [████████████████████] 100.00%
#
# [2] Teknologi Industri Pertanian - Page 3/3 [████████████████████] 100.00%
#
# [3] Agribisnis - Page 3/3 [████████████████████] 100.00%
#
# [4] Agroteknologi - Page 3/3 [████████████████████] 100.00%
#
# [5] Ilmu Kelautan - Page 3/3 [████████████████████] 100.00%
#
# [6] Ekonomi Pembangunan - Page 3/3 [████████████████████] 100.00%
#
# [7] Manajemen - Page 3/3 [████████████████████] 100.00%
#
# [8] Akuntansi - Page 3/3 [████████████████████] 100.00%
#
# [9] Teknik Industri - Page 3/3 [████████████████████] 100.00%
#
# [10] Teknik Informatika - Page 3/3 [████████████████████] 100.00%
#
# [11] Manajemen Informatika - Page 3/3 [████████████████████] 100.00%
#
# [12] Sosiologi - Page 3/3 [████████████████████] 100.00%
#
# [13] Ilmu Komunikasi - Page 3/3 [████████████████████] 100.00%
#
# [14] Psikologi - Page 3/3 [████████████████████] 100.00%
#
# [15] Sastra Inggris - Page 3/3 [████████████████████] 100.00%
#
# [16] Ekonomi Syariah - Page 3/3 [████████████████████] 100.00%
#
# [17] Hukum Bisnis Syariah - Page 3/3 [████████████████████] 100.00%
#
# [18] Pgsd - Page 3/3 [████████████████████] 100.00%
#
# [19] Teknik Multimedia Dan Jaringan - Page 3/3 [████████████████████] 100.00%
#
# [20] Mekatronika - Page 3/3 [████████████████████] 100.00%
#
# [21] D3 Akuntansi - Page 3/3 [████████████████████] 100.00%
#
# [22] Magister Manajemen - Page 3/3 [████████████████████] 100.00%
#
# [23] Teknik Elektro - Page 3/3 [████████████████████] 100.00%
#
# [24] Magister Ilmu Hukum - Page 3/3 [████████████████████] 100.00%
#
# [25] Magister Akuntansi - Page 3/3 [████████████████████] 100.00%
#
# [26] D3 Enterpreneurship - Page 3/3 [████████████████████] 100.00%
#
# [27] Pendidikan Bhs Dan Sastra Indonesia - Page 3/3 [████████████████████] 100.00%
#
# [28] Pendidikan Informatika - Page 3/3 [████████████████████] 100.00%
#
# [29] Pendidikan Ipa - Page 3/3 [████████████████████] 100.00%
#
# [30] Pgpaud - Page 3/3 [████████████████████] 100.00%
#
# [31] Sistem Informasi - Page 3/3 [████████████████████] 100.00%
#
# [32] Teknik Mesin - Page 3/3 [████████████████████] 100.00%
#
# [33] Teknik Mekatronika - Page 3/3 [████████████████████] 100.00%
#
# [34] Journal Jurusan - Page 3/3 [████████████████████] 100.00%
#
# [35] Manajemen Sumberdaya Perairan - Page 3/3 [████████████████████] 100.00%
#
# [36] Magister Ilmu Ekonomi - Page 3/3 [████████████████████] 100.00%
#
# [37] Magister Pengelolaan Sumber Daya Alam - Page 3/3 [████████████████████] 100.00%
#
# [38] Pendidikan Profesi Guru - Page 3/3 [████████████████████] 100.00%
#
# [39] Magister Pendidikan Dasar - Page 3/3 [████████████████████] 100.00%
#
# [40] Doktor Pengelolaan Sumber Daya Alam - Page 3/3 [████████████████████] 100.00%
#
# [41] Doktor Ilmu Manajemen - Page 3/3 [████████████████████] 100.00%
#
#
# ✅ Seluruh link berhasil dikumpulkan!
# 📊 Total entri: 481
# ⏱ Waktu eksekusi: 0 jam 15 menit 14 detik
#       no                                              page  \
# 0      1   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 1      2   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 2      3   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 3      4   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# 4      5   https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# ..   ...                                               ...
# 476  477  https://pta.trunojoyo.ac.id/c_search/byprod/36/2
# 477  478  https://pta.trunojoyo.ac.id/c_search/byprod/36/2
# 478  479  https://pta.trunojoyo.ac.id/c_search/byprod/37/1
# 479  480  https://pta.trunojoyo.ac.id/c_search/byprod/37/1
# 480  481  https://pta.trunojoyo.ac.id/c_search/byprod/37/1
#
#                                            link_keluar
# 0    https://pta.trunojoyo.ac.id/welcome/detail/080...
# 1    https://pta.trunojoyo.ac.id/welcome/detail/080...
# 2    https://pta.trunojoyo.ac.id/welcome/detail/070...
# 3    https://pta.trunojoyo.ac.id/welcome/detail/090...
# 4    https://pta.trunojoyo.ac.id/welcome/detail/070...
# ..                                                 ...
# 476  https://pta.trunojoyo.ac.id/welcome/detail/160...
# 477  https://pta.trunojoyo.ac.id/welcome/detail/160...
# 478  https://pta.trunojoyo.ac.id/welcome/detail/170...
# 479  https://pta.trunojoyo.ac.id/welcome/detail/170...
# 480  https://pta.trunojoyo.ac.id/welcome/detail/170...
#
# [481 rows x 3 columns]

# %% [markdown]
# # Crawling Berita Melalui Website detik.com

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# Fungsi untuk membersihkan konten dari elemen-elemen yang tidak diinginkan
def clean_content(content_element):
    if content_element:
        # Hapus elemen yang berisi daftar isi
        for daftar_isi in ["collapsible"]:
            unwanted = content_element.find("div", id=daftar_isi)
            if unwanted:
                unwanted.decompose()

        # Hapus elemen yang berisi tag
        for tag_class in ["aevp", "detail__body-tag mgt-16"]:
            unwanted = content_element.find_all("div", class_=tag_class)
            for el in unwanted:
                el.decompose()

        # Hapus elemen yang berisi link sisipan
        link_sisip = content_element.find_all("table", class_="linksisip")
        for table in link_sisip:
            table.decompose()

        # Hapus elemen paragraf dan span dengan class 'para_caption'
        unwanted_paragraphs = content_element.find_all(["p", "span"], class_="para_caption")
        for para in unwanted_paragraphs:
            para.decompose()

        # Kembalikan teks yang tersisa
        return content_element.get_text(separator=' ', strip=True).strip()

    return "Content Not Found"

# %%
#Fungsi untuk membersihkan konten artikel
def clean_content(content_element):
    if not content_element:
        return "Content Not Found"
    return " ".join(content_element.stripped_strings)

# Fungsi untuk mengambil data dari halaman web Detik.com
def get_data(url, kategori, min_articles_per_category):
    try:
        response = requests.get(url)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return

    soup = BeautifulSoup(response.content, "html.parser")
    articles = soup.find_all("article", class_="list-content__item")

    for article in articles:
        if len([k for k in kategori_list if k == kategori]) >= min_articles_per_category:
            return  # berhenti jika artikel sudah cukup

        try:
            link = article.find("a")["href"]
            article_response = requests.get(link)
            article_response.raise_for_status()
        except (requests.exceptions.RequestException, TypeError) as e:
            print(f"Request for article failed: {e}")
            continue

        article_soup = BeautifulSoup(article_response.content, "html.parser")
        title_element = article_soup.find("h1", class_="detail__title")
        title = title_element.text.strip() if title_element else "Title Not Found"
        content_element = article_soup.find("div", class_="detail__body-text")
        content = clean_content(content_element)

        judul.append(title)
        isi.append(content)
        kategori_list.append(kategori)

        # tampilkan 10 judul pertama saja sebagai indikator
        if len(judul) <= 100:
            print(title)

# URL kategori Detik
base_urls = [
    "https://news.detik.com/indeks",
    "https://sport.detik.com/indeks",
]

categories = [
    "Politik",
    "Olahraga",
]

# Inisialisasi list untuk menyimpan data
judul = []
isi = []
kategori_list = []

# Batas minimal artikel per kategori
min_articles_per_category = 100

# Looping setiap kategori
for base_url, category in zip(base_urls, categories):
    page = 1
    while len([k for k in kategori_list if k == category]) < min_articles_per_category:
        url = f"{base_url}?page={page}"   # ✅ perbaikan format URL
        get_data(url, category, min_articles_per_category)
        time.sleep(2)
        page += 1

# Buat dataframe
df = pd.DataFrame({"judul": judul, "isi": isi, "kategori": kategori_list})

# Simpan ke CSV
df.to_csv("CrawlBerita_Politik-Olahraga.csv", index=False, encoding="utf-8-sig")

print("✅ Crawling selesai, data disimpan ke CrawlBerita_Politik-Olahraga.csv")
# Out:
# KPK Spill Pucuk Pimpinan Kemenag Terima Dana Korupsi Kuota Haji
# Istana Apresiasi Transformasi Nusakambangan: Kolaborasi untuk Visi-Misi Presiden
# Kapolda Riau Puji Tim Raga Polres Meranti: Garda Terdepan Penjaga Keamanan
# Ini Alasan KPK Periksa Ustaz Khalid Basalamah di Kasus Korupsi Kuota Haji
# Menag Sebut Bakal Ada Lembaga Tampung Dana Umat buat Atasi Kemiskinan
# Menag Doakan Kementerian Haji Raih Survei Kepuasan Jemaah di Atas 90%
# Video: Pihak Keluarga dr Aulia Nilai Tuntutan Para Terdakwa Terlalu Ringan
# Israel Serang Markas Komando di Ibu Kota Yaman
# Video: Polri Bantu Evakuasi Warga Terdampak Banjir dan Longsor di Bali
# Marcella Santoso Ngaku Diancam Terdakwa Suap Migor: Ada Kata Pasang Leher
# Peringati HUT ke-80, TNI AL Gelar Bakti Sosial di Ponpes Bogor
# Polri Salurkan 1.500 Paket Bansos ke Warga Kukar Kaltim
# Tanggul Beton di Utara Jakarta Tuai Tanda Tanya
# Survei BPS: Tingkat Kepuasan Jemaah Haji RI 2025 88,46%, Naik dari Tahun Lalu
# Legislator Harap Tata Kelola Haji Lebih Terintegrasi, Bakal Diawasi Ketat
# Kemensos Gerak Cepat Salurkan Bantuan untuk Korban Banjir Bali
# Mural Baru Banksy Hiasi Pengadilan Tinggi London, Soroti Penindasan Demonstran
# Kapolda Bali Kerahkan Personel Pastikan Penanganan Banjir-Hak Warga Terpenuhi
# Kejari Lebak Ungkap Korupsi di PDAM Tirta Multatuli, Eks Dirut-Dewas Ditahan
# Video Update Korban Banjir di Bali: 9 Orang Meninggal, 6 Hilang
# Korban Tewas Akibat Banjir di Bali Bertambah Jadi 9 Orang, 6 Masih Hilang
# Temuan Baru KPK: Agen Tak Beri Setoran Tak Kebagian Kuota Haji
# Video: Warga di Lumajang Nekat Seberangi Sungai Usai Jembatan Antardesa Ambruk
# Title Not Found
# Operasi Narkoba di Rohul: 3 Tersangka Dijerat, 24 Paket Sabu Disita
# Video: Tim Fakta TAUD Sebut Affan Dilindas Rantis saat Ambil HP
# Kapolda Bali Siapkan Bantuan Trauma Healing untuk Korban Banjir dan Longsor
# Banjir Terjang Bali, Pemkot Denpasar Tetapkan Status Tanggap Darurat Bencana
# Banjir dan Longsor Terjang Bali, Polri Bantu Evakuasi Warga Terdampak
# Bamsoet Ingatkan Dampak Konvergensi Politik dengan Disrupsi Digital
# Video: Demokrat soal Usulan UU Anti-Flexing: yang Penting Sensitif ke Masyarakat
# Anggota BP MPR Soroti Ketimpangan Desentralisasi, Ingatkan Peran Pusat
# Video Investigasi KontraS: Rantis Brimob Pelindas Affan Terbuat dari Baja Tak Akan Rusak
# Aliansi Ojol Curhat di DPR Minta Potongan Tarif 10% Direalisasikan
# Title Not Found
# Polisi-TNI dan Imigrasi Tanam Kelapa di Dumai, 'Emas Hijau' untuk Masa Depan
# KPK Perpanjang Waktu Penahanan Eks Wamenaker Noel
# Jaksa Tampilkan Duit Puluhan M di Brankas, Marcella Santoso Klaim Success Fee
# Terkendala Cuaca, Helikopter Jatuh di Jila Mimika Dievakuasi Besok
# Gempa M 4,6 Guncang Sukabumi
# Video: Legislator Gerindra Rahayu Saraswati Mundur dari DPR
# Aksi Polisi Bagikan Air Mineral dan Roti ke Massa Demo Buruh di Monas
# Duka Pulau Dewata Diterjang Banjir hingga Jatuh Korban Jiwa
# Muncul Kode 'Mendan' dan 'DJ' untuk Hakim di Sidang Suap Vonis Onslag Migor
# Ada Perlindungan Adat hingga Iklim, 4 RUU DPD RI Masuk Prolegnas
# Video: Dua Posisi Menteri Prabowo Masih Kosong, Ini Kata Demokrat
# Polda Banten Gagas Kampung Bhayangkara Mandiri untuk Ketahanan Pangan Desa
# Rutan KPK Penuh, Anak Eks Gubernur Kaltim Ditahan di Rutan Pondok Bambu
# Prabowo Telepon Emir Qatar, Tanya Kondisi Doha Usai Diserang Israel
# Title Not Found
# Waka MPR Dorong Peningkatan Mutu Layanan Kesehatan Jantung di Tanah Air
# Menkeu Purbaya Klarifikasi Unggahan Anaknya soal Lengserkan 'Agen CIA'
# Gempar Serangan Israel ke Qatar
# KPK Juga Usut Dugaan Duit Kasus BJB Dipakai Biayai RK di Pilkada DKI
# Walkot Semarang Luncurkan Program 'KELUARGA CEMARA' untuk Tekan Stunting
# Waka MPR: Teknologi CCS & CCUS Kunci Jawab Tantangan Transisi Energi
# Fraksi Gerindra Akan Nonaktifkan Keponakan Prabowo dari DPR
# Wamensos Serahkan Santunan Kematian Korban Gedung Majelis Ambruk di Bogor
# Perwakilan Buruh Diterima Istana, Sebut Ada Tindak Lanjut UU Ketenagakerjaan
# KPK Sebut Pemeriksaan Lisa Mariana Bukan Cari Sensasi: Diduga Ada Aliran Dana
# Kronologi Kematian Anak Gajah Tari di TN Tesso Nilo, Penyebab Diselidiki
# KPK Periksa Deputi Gubernur BI Fillianingsih Terkait Korupsi Dana CSR Besok
# Rahayu Saraswati Mundur dari Anggota DPR, Sampaikan Permohonan Maaf
# Video Sejumlah Aktivis Jenguk Delpedro-Haris Anhar, Harap Kasus Dihentikan
# Demo Buruh-Ojol di Patung Kuda Bubar, Jalan Merdeka Selatan Kembali Normal
# GP Ansor Tegaskan Dukungan untuk Kementan Berantas Mafia Pangan
# Video Yordania Kecam Serangan Israel ke Qatar: Langgar Kedaulatan Negara
# Kecelakaan 2 Truk di Tol Tangerang-Merak, Pembatas Bahu Jalan Hancur
# Menkeu Purbaya Cerita Dicap Sok Pintar Saat Targetkan Ekonomi RI Tumbuh 6%
# Polda Riau Hidupkan Pengamanan Swakarsa Lewat Green Satkamling
# KPK: Ustaz Khalid Basalamah Jadi Saksi Fakta, Berangkat Haji Pakai Kuota Khusus
# Siswa SMK di Cileungsi Bogor Sementara Belajar dari Rumah Usai Atap Ambruk
# Telepon Kepala BNPB, Prabowo Minta Banjir Bali hingga NTT Ditangani Cepat
# Krisis Air Memburuk, Siprus Andalkan Desalinasi untuk Bertahan dari Kekeringan
# KPK Sudah Kantongi Calon Tersangka Korupsi Kuota Haji, Kapan Diumumkan?
# Kapolri Ajak Komnas HAM Bersinergi Awasi Pelaksanaan Pengamanan Unjuk Rasa
# Eks Kaprodi PPDS Anestesi Undip Taufik Dituntut 3 Tahun Bui di Kasus dr Aulia
# Forum Internasional di Jakarta Dorong Kolaborasi Menuju Net Zero
# Mengubah Kasus Jadi Momentum: Masa Depan Stem Cell Indonesia
# Raih Penghargaan BKN, Herman Deru Perkuat Sinergi Meritokrasi Regional
# Audiensi dengan Kapolri, Komnas HAM Pastikan Hak Tersangka Demo Anarkis Terpenuhi
# Ditawari 1 Juta Dolar AS, Eks Ketua PN Jakpus Kenal Agusrin di Rumah Ketua MA
# Video: Fakta Baru soal Temuan Ladang Ganja di Blitar dari Perusuh
# 5 Berita Terpopuler Internasional Hari Ini
# Drone-drone Rusia Masuk ke Wilayah Polandia, NATO Turun Tangan
# Prajurit TNI Diduga Terlibat Pembunuhan Kacab Bank, Diperiksa Polisi Militer
# Koalisi Sipil Kritik Kemhan yang Adukan Berita soal Rencana Darurat Militer
# Menteri Agus Dorong Rutan-Lapas Pakai Lahan Idle Dukung Hilirisasi Kelapa
# Kemhan Adukan Berita soal Rencana Darurat Militer ke Dewan Pers
# Menkeu Purbaya Menghadap Prabowo Usai Rapat Kerja Perdana di DPR
# Ditahan KPK, Anak Eks Gubernur Kaltim Terima Rp 3,5 Miliar untuk Urus IUP
# Korban Tewas Banjir Bali Terjebak di Mobil, Terseret Arus ke Proyek Vila
# Guru SMA di Boyolali Diduga Injak Siswa, Warga Geruduk Sekolah
# Title Not Found
# Video: Momen Gibran Panen Lobster Bareng Titiek Soeharto-Trenggono
# Video: Kondisi Gedung Parlemen Nepal Porak Poranda Usai Demo Berdarah
# Ledakan Guncang Pangkalan Militer Korsel, 10 Tentara Luka
# Apa Itu Gelombang Ekuatorial Rossby? Picu Hujan Deras hingga Banjir di Bali
# Napi di Nusakambangan Produksi Material Bangunan Berbahan Dasar FABA
# Polisi Jadwalkan Ulang Pemanggilan Sherina Terkait Kucing Uya Kuya Jumat Besok
# ✅ Crawling selesai, data disimpan ke CrawlBerita_Politik-Olahraga.csv

# %%
df=pd.read_csv("CrawlBerita_Politik-Olahraga.csv")
df.head(200)
# Out:
#                                                  judul  \
# 0    KPK Spill Pucuk Pimpinan Kemenag Terima Dana K...
# 1    Istana Apresiasi Transformasi Nusakambangan: K...
# 2    Kapolda Riau Puji Tim Raga Polres Meranti: Gar...
# 3    Ini Alasan KPK Periksa Ustaz Khalid Basalamah ...
# 4    Menag Sebut Bakal Ada Lembaga Tampung Dana Uma...
# ..                                                 ...
# 195  Semarak Bendera Palestina dalam Balap Sepeda d...
# 196  Tatap MotoGP Catalunya, Francesco Bagnaia Suda...
# 197    Komang Ayu Cahya Dewi Mundur dari Pelatnas PBSI
# 198  Penghormatan untuk Kobe Bryant pada Mamba Day ...
# 199  Aksi Tolak Tim Israel dalam Balapan Sepeda di ...
#
#                                                    isi  kategori
# 0    Jakarta - KPK mengungkap adanya dugaan aliran ...   Politik
# 1    Cilacap - Kantor Komunikasi Kepresidenan atau ...   Politik
# 2    Jakarta - Kapolda Riau, Irjen Pol Herry Heryaw...   Politik
# 3    Jakarta - KPK telah memeriksa Ustaz Khalid Zee...   Politik
# 4    Jakarta - Menteri Agama (Menag) Nasaruddin Uma...   Politik
# ..                                                 ...       ...
# 195  Bilbao - Penonton mengibarkan bendera Palestin...  Olahraga
# 196  Jakarta - Rider Ducati , Francesco Bagnaia , o...  Olahraga
# 197  Jakarta - Komang Ayu Cahya Dewi mundur dari pe...  Olahraga
# 198  Jakarta - Project 95 (P95) Basketball Academy ...  Olahraga
# 199  Bilbao - Balapan sepeda La Vuelta 2025 di Span...  Olahraga
#
# [200 rows x 3 columns]
